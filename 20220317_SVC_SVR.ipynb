# %% [markdown]
# <a href="https://colab.research.google.com/github/kiyong21c/nadocoding/blob/master/20220317_SVC_SVR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # SVM(Support Vector Machine)
#
# > 크게 SVC(분류,Classification), SVR(회귀, Regression) 로 나눈다.
#
#  - SVC는 일반적으로 이진분류(Class를 0 또는 1 등으로 나눈), 다중클래스분류도 가능하다(1:N)
#
#   -  SVC에서 사용할 수 있는 분류 모델
#
#     1. LinearSVC : 커널트릭 미지원(하지만, 3차원 공간에서 경계면으로 분류가능)
#
#     2. SVC : 커널트릭 지원(poly, rbf 등)
#
#  - SVR은 마진 안으로 적당히 많은 데이터값이 들어오도록 한다.
#   - SVR에서 사용할 수 있는 분류 모델
#
#     1. LinearSVR
#
#     2. SVR

# %% [markdown]
# # SVC의 LinearSVC 분류모델 사용하여 이진분류 시각화
# https://blog.naver.com/ssdyka/221235323434

# %% [markdown]
# ### 2가지 클래스 분류/회귀

# %%
# 두가지 선형 분류/회귀 모델
from sklearn.linear_model import LogisticRegression # 대표적 이진회귀 알고리즘인 로지스틱회귀 모델
from sklearn.svm import LinearSVC # 대표적 이진분류 알고리즘 선형서포트벡터분류 모델
import matplotlib.pyplot as plt
import seaborn as sns
# 결정경계 시각화
from mlxtend.plotting import plot_decision_regions

# 데이터 가져오기
from sklearn.datasets import make_blobs
X, y = make_blobs(centers=2, random_state=8)

# 모델정의
model1 = LinearSVC() # 2진 이상의 분류도 가능
model2 = LogisticRegression() # 2진 이상의 분류도 가능


plt.figure(figsize=(12, 5))
for idx, (model, title) in enumerate(zip([model1, model2], ["LinearSVC", "LogisticRegression"])):
  # 학습
  clf = model.fit(X, y)
  # 시각화
  plt.subplot(1,2, idx+1)
  sns.scatterplot(X[:, 0], X[:, 1], hue=y)
  # 시각화(2D 경계 시각화 모듈 활용)
  plot_decision_regions(X, y, clf=model, legend=2) # clf파라미터에는 적용할 "모델"을 넣는다
  plt.title(title)
  plt.xticks([])
  plt.yticks([])
  plt.xlabel("w[0]")
  plt.ylabel("w[1]")

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/mlxtend/plotting/decision_regions.py:244: MatplotlibDeprecationWarning: Passing unsupported keyword arguments to axis() will raise a TypeError in 3.3.
#   ax.axis(xmin=xx.min(), xmax=xx.max(), y_min=yy.min(), y_max=yy.max())
# ...

# %% [markdown]
# ### 멀티클래스 분류/회귀

# %%
# 두가지 선형 분류/회귀 모델
from sklearn.linear_model import LogisticRegression # 대표적 이진회귀 알고리즘인 로지스틱회귀 모델
from sklearn.svm import LinearSVC # 대표적 이진분류 알고리즘 선형서포트벡터분류 모델
import matplotlib.pyplot as plt
import seaborn as sns
# 결정경계 시각화
from mlxtend.plotting import plot_decision_regions

# 데이터 가져오기
from sklearn.datasets import make_blobs
X, y = make_blobs(centers=3, random_state=8)

# 모델정의
model1 = LinearSVC() # 2진 이상의 분류도 가능
model2 = LogisticRegression() # 2진 이상의 분류도 가능


plt.figure(figsize=(12, 5))
for idx, (model, title) in enumerate(zip([model1, model2], ["LinearSVC", "LogisticRegression"])):
  # 학습
  clf = model.fit(X, y)
  # 시각화
  plt.subplot(1,2, idx+1)
  sns.scatterplot(X[:, 0], X[:, 1], hue=y)
  # 시각화(2D 경계 시각화 모듈 활용)
  plot_decision_regions(X, y, clf=model, legend=2) # clf파라미터에는 적용할 "모델 또는 학습된모델"을 넣는다
  plt.title(title)
  plt.xticks([])
  plt.yticks([])
  plt.xlabel("w[0]")
  plt.ylabel("w[1]")

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/mlxtend/plotting/decision_regions.py:244: MatplotlibDeprecationWarning: Passing unsupported keyword arguments to axis() will raise a TypeError in 3.3.
#   ax.axis(xmin=xx.min(), xmax=xx.max(), y_min=yy.min(), y_max=yy.max())
# ...

# %% [markdown]
# # SVC의 커널을 사용하여 분류
#  - 새로운 특성 또는 알려진 커널(poly, rbf 등)을 적용하여 축을 추가 → 차원확장

# %% [markdown]
# ### 선형으로 구분되지 않는 클래스를 가진 데이터

# %%
# 두가지 선형 분류/회귀 모델
from sklearn.linear_model import LogisticRegression # 대표적 이진회귀 알고리즘인 로지스틱회귀 모델
from sklearn.svm import LinearSVC # 대표적 이진분류 알고리즘 선형서포트벡터분류 모델
import matplotlib.pyplot as plt
import seaborn as sns
# 결정경계 시각화
from mlxtend.plotting import plot_decision_regions

# 데이터 가져오기
from sklearn.datasets import make_blobs
X, y = make_blobs(centers=4, random_state=8)
y = y%2 # 0,1,2,3 → 0,1

# 모델생성 및 학습
clf = LinearSVC().fit(X, y)

# 시각화
sns.scatterplot(X[:, 0], X[:, 1], hue=y)
# 시각화(2D 경계 시각화 모듈 활용)
plot_decision_regions(X, y, clf=clf, legend=2) # clf파라미터에는 적용할 "모델 또는 학습된모델"을 넣는다
plt.xlabel("attr 0")
plt.ylabel("attr 1")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/mlxtend/plotting/decision_regions.py:244: MatplotlibDeprecationWarning: Passing unsupported keyword arguments to axis() will raise a TypeError in 3.3.
#   ax.axis(xmin=xx.min(), xmax=xx.max(), y_min=yy.min(), y_max=yy.max())

# %% [markdown]
# 이러한 데이터셋에는 선형 분류 모델은 적합하지 않다
#
# → 특성을 제곱한 특성 축을 추가해 차원을 확장해보자
